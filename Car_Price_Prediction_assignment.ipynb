# %% [markdown]
# <a href="https://colab.research.google.com/github/hammadmustafa-alt/Deep-Learning/blob/main/Car_Price_Prediction_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Car Price Prediction::

# %% [markdown]
# Download dataset from this link:
#
# https://www.kaggle.com/hellbuoy/car-price-prediction

# %% [markdown]
# # Problem Statement::

# %% [markdown]
# A Chinese automobile company Geely Auto aspires to enter the US market by setting up their manufacturing unit there and producing cars locally to give competition to their US and European counterparts.
#
# They have contracted an automobile consulting company to understand the factors on which the pricing of cars depends. Specifically, they want to understand the factors affecting the pricing of cars in the American market, since those may be very different from the Chinese market. The company wants to know:
#
# Which variables are significant in predicting the price of a car
# How well those variables describe the price of a car
# Based on various market surveys, the consulting firm has gathered a large data set of different types of cars across the America market.
#
# # task::
# We are required to model the price of cars with the available independent variables. It will be used by the management to understand how exactly the prices vary with the independent variables. They can accordingly manipulate the design of the cars, the business strategy etc. to meet certain price levels. Further, the model will be a good way for management to understand the pricing dynamics of a new market.

# %% [markdown]
# # WORKFLOW ::

# %% [markdown]
# 1.Load Data
#
# 2.Check Missing Values ( If Exist ; Fill each record with mean of its feature )
#
# 3.Split into 50% Training(Samples,Labels) , 30% Test(Samples,Labels) and 20% Validation Data(Samples,Labels).
#
# 4.Model : input Layer (No. of features ), 3 hidden layers including 10,8,6 unit & Output Layer with activation function relu/tanh (check by experiment).
#
# 5.Compilation Step (Note : Its a Regression problem , select loss , metrics according to it)
# 6.Train the Model with Epochs (100) and validate it
#
# 7.If the model gets overfit tune your model by changing the units , No. of layers , activation function , epochs , add dropout layer or add Regularizer according to the need .
#
# 8.Evaluation Step
#
# 9.Prediction

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd

car_data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/CarPrice_Assignment.csv')

# %%
import tensorflow as tf

car_data.head()
# Out:
#    car_ID  symboling                   CarName  ... citympg highwaympg    price
# 0       1          3        alfa-romero giulia  ...      21         27  13495.0
# 1       2          3       alfa-romero stelvio  ...      21         27  16500.0
# 2       3          1  alfa-romero Quadrifoglio  ...      19         26  16500.0
# 3       4          2               audi 100 ls  ...      24         30  13950.0
# 4       5          2                audi 100ls  ...      18         22  17450.0
#
# [5 rows x 26 columns]

# %%
car_data.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
car_data['CarName'].unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
#        'mazda glc deluxe', 'mazda 626', 'mazda glc', 'mazda rx-7 gs',
#        'mazda glc 4', 'mazda glc custom l', 'mazda glc custom',
#        'buick electra 225 custom', 'buick century luxus (sw)',
#        'buick century', 'buick skyhawk', 'buick opel isuzu deluxe',
#        'buick skylark', 'buick century special',
#        'buick regal sport coupe (turbo)', 'mercury cougar',
#        'mitsubishi mirage', 'mitsubishi lancer', 'mitsubishi outlander',
#        'mitsubishi g4', 'mitsubishi mirage g4', 'mitsubishi montero',
#        'mitsubishi pajero', 'Nissan versa', 'nissan gt-r', 'nissan rogue',
#        'nissan latio', 'nissan titan', 'nissan leaf', 'nissan juke',
#        'nissan note', 'nissan clipper', 'nissan nv200', 'nissan dayz',
#        'nissan fuga', 'nissan otti', 'nissan teana', 'nissan kicks',
#        'peugeot 504', 'peugeot 304', 'peugeot 504 (sw)', 'peugeot 604sl',
#        'peugeot 505s turbo diesel', 'plymouth fury iii',
#        'plymouth cricket', 'plymouth satellite custom (sw)',
#        'plymouth fury gran sedan', 'plymouth valiant', 'plymouth duster',
#        'porsche macan', 'porcshce panamera', 'porsche cayenne',
#        'porsche boxter', 'renault 12tl', 'renault 5 gtl', 'saab 99e',
#        'saab 99le', 'saab 99gle', 'subaru', 'subaru dl', 'subaru brz',
#        'subaru baja', 'subaru r1', 'subaru r2', 'subaru trezia',
#        'subaru tribeca', 'toyota corona mark ii', 'toyota corona',
#        'toyota corolla 1200', 'toyota corona hardtop',
#        'toyota corolla 1600 (sw)', 'toyota carina', 'toyota mark ii',
#        'toyota corolla', 'toyota corolla liftback',
#        'toyota celica gt liftback', 'toyota corolla tercel',
#        'toyota corona liftback', 'toyota starlet', 'toyota tercel',
#        'toyota cressida', 'toyota celica gt', 'toyouta tercel',
#        'vokswagen rabbit', 'volkswagen 1131 deluxe sedan',
#        'volkswagen model 111', 'volkswagen type 3', 'volkswagen 411 (sw)',
#        'volkswagen super beetle', 'volkswagen dasher', 'vw dasher',
#        'vw rabbit', 'volkswagen rabbit', 'volkswagen rabbit custom',
#        'volvo 145e (sw)', 'volvo 144ea', 'volvo 244dl', 'volvo 245',
#        'volvo 264gl', 'volvo diesel', 'volvo 246'], dtype=object)

# %%
np.where(car_data.applymap(lambda x: x ==''))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
car_data.isnull().any()
# Out:
# car_ID              False
# symboling           False
# CarName             False
# fueltype            False
# aspiration          False
# doornumber          False
# carbody             False
# drivewheel          False
# enginelocation      False
# wheelbase           False
# carlength           False
# carwidth            False
# carheight           False
# curbweight          False
# enginetype          False
# cylindernumber      False
# enginesize          False
# fuelsystem          False
# boreratio           False
# stroke              False
# compressionratio    False
# horsepower          False
# peakrpm             False
# citympg             False
# highwaympg          False
# price               False
# dtype: bool

# %%
car_data.iloc[3,2] = 'audi 100ls'

# %%
car_data.drop(columns=['car_ID'], inplace=True)

# %%
car_data.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
final_car = pd.get_dummies(car_data, columns=['CarName','symboling','fueltype',	'aspiration',	'doornumber',	'carbody',	'drivewheel',	
                                              'enginelocation',	'enginetype',	'cylindernumber',	'fuelsystem'], drop_first = True)

# %%
final_car.head()
# Out:
#    wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 0       88.6      168.8  ...                0                0
# 1       88.6      168.8  ...                0                0
# 2       94.5      171.2  ...                0                0
# 3       99.8      176.6  ...                0                0
# 4       99.4      176.6  ...                0                0
#
# [5 rows x 193 columns]

# %%
final_car.describe()
# Out:
#         wheelbase   carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# count  205.000000  205.000000  ...       205.000000       205.000000
# mean    98.756585  174.049268  ...         0.043902         0.004878
# std      6.021776   12.337289  ...         0.205380         0.069843
# min     86.600000  141.100000  ...         0.000000         0.000000
# 25%     94.500000  166.300000  ...         0.000000         0.000000
# 50%     97.000000  173.200000  ...         0.000000         0.000000
# 75%    102.400000  183.100000  ...         0.000000         0.000000
# max    120.900000  208.100000  ...         1.000000         1.000000
#
# [8 rows x 193 columns]

# %%
np.random.seed(11111)
msk = np.random.rand(len(final_car)) < 0.72
train_total = final_car[msk]
test_total = final_car[~msk]

# %%
print(len(train_total))
print(len(test_total))
# Out:
# 141
# 64

# %%
train_total.head(10)
# Out:
#     wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 1        88.6      168.8  ...                0                0
# 2        94.5      171.2  ...                0                0
# 3        99.8      176.6  ...                0                0
# 4        99.4      176.6  ...                0                0
# 5        99.8      177.3  ...                0                0
# 6       105.8      192.7  ...                0                0
# 7       105.8      192.7  ...                0                0
# 8       105.8      192.7  ...                0                0
# 9        99.5      178.2  ...                0                0
# 11      101.2      176.8  ...                0                0
#
# [10 rows x 193 columns]

# %%
train_total.describe()
# Out:
#         wheelbase   carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# count  141.000000  141.000000  ...       141.000000       141.000000
# mean    98.692199  173.658156  ...         0.035461         0.007092
# std      6.005665   12.320089  ...         0.185601         0.084215
# min     86.600000  144.600000  ...         0.000000         0.000000
# 25%     94.500000  166.300000  ...         0.000000         0.000000
# 50%     96.500000  172.400000  ...         0.000000         0.000000
# 75%    102.400000  180.300000  ...         0.000000         0.000000
# max    115.600000  202.600000  ...         1.000000         1.000000
#
# [8 rows x 193 columns]

# %%
print(train_total.dtypes)
# Out:
# wheelbase          float64
# carlength          float64
# carwidth           float64
# carheight          float64
# curbweight           int64
#                     ...
# fuelsystem_idi       uint8
# fuelsystem_mfi       uint8
# fuelsystem_mpfi      uint8
# fuelsystem_spdi      uint8
# fuelsystem_spfi      uint8
# Length: 193, dtype: object

# %%
train_label = train_total.loc[:,'price']
test_label = test_total.loc[:,'price']

# %%
train_label
# Out:
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
# 5      15250.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 141, dtype: float64

# %%
test_data = test_total.drop(columns = ['price'])
train_data = train_total.drop(columns = ['price'])

# %%
train_data.shape[1]
# Out:
# 192

# %%
train_data
# Out:
#      wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 1         88.6      168.8  ...                0                0
# 2         94.5      171.2  ...                0                0
# 3         99.8      176.6  ...                0                0
# 4         99.4      176.6  ...                0                0
# 5         99.8      177.3  ...                0                0
# ..         ...        ...  ...              ...              ...
# 200      109.1      188.8  ...                0                0
# 201      109.1      188.8  ...                0                0
# 202      109.1      188.8  ...                0                0
# 203      109.1      188.8  ...                0                0
# 204      109.1      188.8  ...                0                0
#
# [141 rows x 192 columns]

# %%
{train_data.columns.get_loc(c): c for idx, c in enumerate(train_data.columns)}
# Out:
# {0: 'wheelbase',
#  1: 'carlength',
#  2: 'carwidth',
#  3: 'carheight',
#  4: 'curbweight',
#  5: 'enginesize',
#  6: 'boreratio',
#  7: 'stroke',
#  8: 'compressionratio',
#  9: 'horsepower',
#  10: 'peakrpm',
#  11: 'citympg',
#  12: 'highwaympg',
#  13: 'CarName_alfa-romero Quadrifoglio',
#  14: 'CarName_alfa-romero giulia',
#  15: 'CarName_alfa-romero stelvio',
#  16: 'CarName_audi 100ls',
#  17: 'CarName_audi 4000',
#  18: 'CarName_audi 5000',
#  19: 'CarName_audi 5000s (diesel)',
#  20: 'CarName_audi fox',
#  21: 'CarName_bmw 320i',
#  22: 'CarName_bmw x1',
#  23: 'CarName_bmw x3',
#  24: 'CarName_bmw x4',
#  25: 'CarName_bmw x5',
#  26: 'CarName_bmw z4',
#  27: 'CarName_buick century',
#  28: 'CarName_buick century luxus (sw)',
#  29: 'CarName_buick century special',
#  30: 'CarName_buick electra 225 custom',
#  31: 'CarName_buick opel isuzu deluxe',
#  32: 'CarName_buick regal sport coupe (turbo)',
#  33: 'CarName_buick skyhawk',
#  34: 'CarName_buick skylark',
#  35: 'CarName_chevrolet impala',
#  36: 'CarName_chevrolet monte carlo',
#  37: 'CarName_chevrolet vega 2300',
#  38: 'CarName_dodge challenger se',
#  39: 'CarName_dodge colt (sw)',
#  40: 'CarName_dodge colt hardtop',
#  41: 'CarName_dodge coronet custom',
#  42: 'CarName_dodge coronet custom (sw)',
#  43: 'CarName_dodge d200',
#  44: 'CarName_dodge dart custom',
#  45: 'CarName_dodge monaco (sw)',
#  46: 'CarName_dodge rampage',
#  47: 'CarName_honda accord',
#  48: 'CarName_honda accord cvcc',
#  49: 'CarName_honda accord lx',
#  50: 'CarName_honda civic',
#  51: 'CarName_honda civic (auto)',
#  52: 'CarName_honda civic 1300',
#  53: 'CarName_honda civic 1500 gl',
#  54: 'CarName_honda civic cvcc',
#  55: 'CarName_honda prelude',
#  56: 'CarName_isuzu D-Max ',
#  57: 'CarName_isuzu D-Max V-Cross',
#  58: 'CarName_isuzu MU-X',
#  59: 'CarName_jaguar xf',
#  60: 'CarName_jaguar xj',
#  61: 'CarName_jaguar xk',
#  62: 'CarName_maxda glc deluxe',
#  63: 'CarName_maxda rx3',
#  64: 'CarName_mazda 626',
#  65: 'CarName_mazda glc',
#  66: 'CarName_mazda glc 4',
#  67: 'CarName_mazda glc custom',
#  68: 'CarName_mazda glc custom l',
#  69: 'CarName_mazda glc deluxe',
#  70: 'CarName_mazda rx-4',
#  71: 'CarName_mazda rx-7 gs',
#  72: 'CarName_mazda rx2 coupe',
#  73: 'CarName_mercury cougar',
#  74: 'CarName_mitsubishi g4',
#  75: 'CarName_mitsubishi lancer',
#  76: 'CarName_mitsubishi mirage',
#  77: 'CarName_mitsubishi mirage g4',
#  78: 'CarName_mitsubishi montero',
#  79: 'CarName_mitsubishi outlander',
#  80: 'CarName_mitsubishi pajero',
#  81: 'CarName_nissan clipper',
#  82: 'CarName_nissan dayz',
#  83: 'CarName_nissan fuga',
#  84: 'CarName_nissan gt-r',
#  85: 'CarName_nissan juke',
#  86: 'CarName_nissan kicks',
#  87: 'CarName_nissan latio',
#  88: 'CarName_nissan leaf',
#  89: 'CarName_nissan note',
#  90: 'CarName_nissan nv200',
#  91: 'CarName_nissan otti',
#  92: 'CarName_nissan rogue',
#  93: 'CarName_nissan teana',
#  94: 'CarName_nissan titan',
#  95: 'CarName_peugeot 304',
#  96: 'CarName_peugeot 504',
#  97: 'CarName_peugeot 504 (sw)',
#  98: 'CarName_peugeot 505s turbo diesel',
#  99: 'CarName_peugeot 604sl',
#  100: 'CarName_plymouth cricket',
#  101: 'CarName_plymouth duster',
#  102: 'CarName_plymouth fury gran sedan',
#  103: 'CarName_plymouth fury iii',
#  104: 'CarName_plymouth satellite custom (sw)',
#  105: 'CarName_plymouth valiant',
#  106: 'CarName_porcshce panamera',
#  107: 'CarName_porsche boxter',
#  108: 'CarName_porsche cayenne',
#  109: 'CarName_porsche macan',
#  110: 'CarName_renault 12tl',
#  111: 'CarName_renault 5 gtl',
#  112: 'CarName_saab 99e',
#  113: 'CarName_saab 99gle',
#  114: 'CarName_saab 99le',
#  115: 'CarName_subaru',
#  116: 'CarName_subaru baja',
#  117: 'CarName_subaru brz',
#  118: 'CarName_subaru dl',
#  119: 'CarName_subaru r1',
#  120: 'CarName_subaru r2',
#  121: 'CarName_subaru trezia',
#  122: 'CarName_subaru tribeca',
#  123: 'CarName_toyota carina',
#  124: 'CarName_toyota celica gt',
#  125: 'CarName_toyota celica gt liftback',
#  126: 'CarName_toyota corolla',
#  127: 'CarName_toyota corolla 1200',
#  128: 'CarName_toyota corolla 1600 (sw)',
#  129: 'CarName_toyota corolla liftback',
#  130: 'CarName_toyota corolla tercel',
#  131: 'CarName_toyota corona',
#  132: 'CarName_toyota corona hardtop',
#  133: 'CarName_toyota corona liftback',
#  134: 'CarName_toyota corona mark ii',
#  135: 'CarName_toyota cressida',
#  136: 'CarName_toyota mark ii',
#  137: 'CarName_toyota starlet',
#  138: 'CarName_toyota tercel',
#  139: 'CarName_toyouta tercel',
#  140: 'CarName_vokswagen rabbit',
#  141: 'CarName_volkswagen 1131 deluxe sedan',
#  142: 'CarName_volkswagen 411 (sw)',
#  143: 'CarName_volkswagen dasher',
#  144: 'CarName_volkswagen model 111',
#  145: 'CarName_volkswagen rabbit',
#  146: 'CarName_volkswagen rabbit custom',
#  147: 'CarName_volkswagen super beetle',
#  148: 'CarName_volkswagen type 3',
#  149: 'CarName_volvo 144ea',
#  150: 'CarName_volvo 145e (sw)',
#  151: 'CarName_volvo 244dl',
#  152: 'CarName_volvo 245',
#  153: 'CarName_volvo 246',
#  154: 'CarName_volvo 264gl',
#  155: 'CarName_volvo diesel',
#  156: 'CarName_vw dasher',
#  157: 'CarName_vw rabbit',
#  158: 'symboling_-1',
#  159: 'symboling_0',
#  160: 'symboling_1',
#  161: 'symboling_2',
#  162: 'symboling_3',
#  163: 'fueltype_gas',
#  164: 'aspiration_turbo',
#  165: 'doornumber_two',
#  166: 'carbody_hardtop',
#  167: 'carbody_hatchback',
#  168: 'carbody_sedan',
#  169: 'carbody_wagon',
#  170: 'drivewheel_fwd',
#  171: 'drivewheel_rwd',
#  172: 'enginelocation_rear',
#  173: 'enginetype_dohcv',
#  174: 'enginetype_l',
#  175: 'enginetype_ohc',
#  176: 'enginetype_ohcf',
#  177: 'enginetype_ohcv',
#  178: 'enginetype_rotor',
#  179: 'cylindernumber_five',
#  180: 'cylindernumber_four',
#  181: 'cylindernumber_six',
#  182: 'cylindernumber_three',
#  183: 'cylindernumber_twelve',
#  184: 'cylindernumber_two',
#  185: 'fuelsystem_2bbl',
#  186: 'fuelsystem_4bbl',
#  187: 'fuelsystem_idi',
#  188: 'fuelsystem_mfi',
#  189: 'fuelsystem_mpfi',
#  190: 'fuelsystem_spdi',
#  191: 'fuelsystem_spfi'}

# %%
mean = train_data.iloc[:,0:13].mean(axis=0)
train_data.iloc[:,0:13] -= mean
std = train_data.iloc[:,0:13].std(axis=0)
train_data.iloc[:,0:13] /= std
test_data.iloc[:,0:13] -= mean
test_data.iloc[:,0:13] /= std

# %%
mean
# Out:
# wheelbase             98.692199
# carlength            173.658156
# carwidth              65.875887
# carheight             53.648227
# curbweight          2546.787234
# enginesize           125.666667
# boreratio              3.324184
# stroke                 3.256809
# compressionratio      10.070355
# horsepower           103.702128
# peakrpm             5143.971631
# citympg               25.113475
# highwaympg            30.581560
# dtype: float64

# %%
std
# Out:
# wheelbase             6.005665
# carlength            12.320089
# carwidth              2.188604
# carheight             2.508204
# curbweight          529.769152
# enginesize           41.733451
# boreratio             0.266123
# stroke                0.296387
# compressionratio      3.868579
# horsepower           38.424275
# peakrpm             474.472458
# citympg               6.509435
# highwaympg            6.734937
# dtype: float64

# %%
mean_label = train_label.mean()
train_label -= mean_label
std_label = train_label.std()
train_label /= std_label
test_label -= mean_label
test_label /= std_label

# %%
test_data.head(10)
# Out:
#     wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 0   -1.680447  -0.394328  ...                0                0
# 10   0.417573   0.255018  ...                0                0
# 14   0.800544   1.245271  ...                0                0
# 15   0.800544   1.245271  ...                0                0
# 18  -1.713748  -2.642688  ...                0                0
# 26  -0.831248  -1.327763  ...                0                0
# 27  -0.831248  -1.327763  ...                0                0
# 32  -0.831248  -1.920291  ...                0                0
# 34  -0.831248  -1.920291  ...                0                0
# 38  -0.365022  -0.499847  ...                0                0
#
# [10 rows x 192 columns]

# %%
print(mean_label)
# Out:
# 13379.132390070921

# %%
std_label
# Out:
# 8189.4945680106175

# %%
test = np.array(test_data.iloc[:]).astype('float32')

train = np.array(train_data.iloc[:]).astype('float32')

test_l= np.array(test_label.astype('float32'))

train_l= np.array(train_label.astype('float32'))

# %% [markdown]
# # Models section

# %%
from keras import models
from keras import layers
def build_model(act):
  model = models.Sequential()
  model.add(layers.Dense(128, activation= act,input_shape=(train.shape[1],)))
  model.add(layers.Dense(64, activation= act))
  model.add(layers.Dense(32, activation= act))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model('relu').summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               24704
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 35,073
# Trainable params: 35,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
build_model('tanh').summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 128)               24704
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 35,073
# Trainable params: 35,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import regularizers
def build_model_regular(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001),input_shape=(train.shape[1],)))
  model.add(layers.Dense(8, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(6, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model('tanh').summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 128)               24704
# _________________________________________________________________
# dense_9 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_10 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 35,073
# Trainable params: 35,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import regularizers
def build_model_drop(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation= act,input_shape=(train.shape[1],)))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(8, activation= act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(6, activation= act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model_drop('relu').summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 10)                1930
# _________________________________________________________________
# dropout (Dropout)            (None, 10)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 8)                 88
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_14 (Dense)             (None, 6)                 54
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6)                 0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 2,079
# Trainable params: 2,079
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # K Fold validation section

# %%
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_relu = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_relu.append(val_mae)
# Out:
# processing fold # 0
# processing fold # 1
# processing fold # 2
# processing fold # 3

# %%
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_tanh = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model('tanh')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_tanh.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_test_function.<locals>.test_function at 0x7f443b6a9e60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4422546170> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4421cce050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f44266b6560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_regular = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model_regular('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_regular.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4424050710> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f441f8f53b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f441e721d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4426fc1200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_drop = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model_drop('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=1)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=1)
  all_scores_drop.append(val_mae)
# Out:
# processing fold # 0
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 0.5703 - mae: 0.5881
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6683 - mae: 0.5263
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6179 - mae: 0.4667
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.2222 - mae: 0.6599
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7481 - mae: 0.5253
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5205 - mae: 0.4315
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6854 - mae: 0.4806
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6969 - mae: 0.4704
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7727 - mae: 0.4967
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3850 - mae: 0.3481
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7023 - mae: 0.4619
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6431 - mae: 0.4962
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8280 - mae: 0.5316
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.1002 - mae: 0.6524
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6387 - mae: 0.5085
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.1635 - mae: 0.6675
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6191 - mae: 0.4762
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.9966 - mae: 0.5590
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6488 - mae: 0.4710
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.1913 - mae: 0.6084
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6555 - mae: 0.4313
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6332 - mae: 0.4374
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4016 - mae: 0.4132
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7166 - mae: 0.5091
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6483 - mae: 0.4740
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5520 - mae: 0.4384
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4627 - mae: 0.4153
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4786 - mae: 0.4241
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8437 - mae: 0.5247
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7711 - mae: 0.4847
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3936 - mae: 0.4046
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8882 - mae: 0.5477
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5708 - mae: 0.4692
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5672 - mae: 0.4918
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5926 - mae: 0.5026
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6913 - mae: 0.4970
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6165 - mae: 0.4720
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5088 - mae: 0.4165
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6230 - mae: 0.4965
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4283 - mae: 0.4116
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3137 - mae: 0.3455
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4070 - mae: 0.4099
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7347 - mae: 0.5039
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5190 - mae: 0.4408
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3575 - mae: 0.3640
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5620 - mae: 0.4776
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4182 - mae: 0.4579
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4495 - mae: 0.4215
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6748 - mae: 0.5326
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5824 - mae: 0.4951
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5631 - mae: 0.4485
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3321 - mae: 0.3566
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5803 - mae: 0.5225
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4809 - mae: 0.4663
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6026 - mae: 0.4691
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5896 - mae: 0.4712
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2672 - mae: 0.3462
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3877 - mae: 0.4228
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2780 - mae: 0.3440
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4159 - mae: 0.3714
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3467 - mae: 0.3847
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4713 - mae: 0.4485
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2807 - mae: 0.3568
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3598 - mae: 0.3584
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4438 - mae: 0.3972
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3858 - mae: 0.3684
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5032 - mae: 0.4689
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2742 - mae: 0.3521
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4771 - mae: 0.4355
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3332 - mae: 0.3519
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3758 - mae: 0.4150
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3411 - mae: 0.3766
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3676 - mae: 0.3801
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5723 - mae: 0.4322
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5817 - mae: 0.4559
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3617 - mae: 0.4147
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2381 - mae: 0.3236
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2264 - mae: 0.3182
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6918 - mae: 0.5007
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4711 - mae: 0.4160
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4826 - mae: 0.4768
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4513 - mae: 0.4269
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5688 - mae: 0.5270
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3858 - mae: 0.4085
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6393 - mae: 0.4544
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6897 - mae: 0.4963
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5714 - mae: 0.4731
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4812 - mae: 0.4366
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3915 - mae: 0.4208
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4611 - mae: 0.4242
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4097 - mae: 0.4328
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4805 - mae: 0.4064
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3612 - mae: 0.4262
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3838 - mae: 0.4484
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4283 - mae: 0.4419
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4570 - mae: 0.4504
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3861 - mae: 0.4278
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6104 - mae: 0.5215
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4836 - mae: 0.4500
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4476 - mae: 0.4238
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f441f85b0e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5289 - mae: 0.5210
# processing fold # 1
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 0.9350 - mae: 0.7287
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4632 - mae: 0.5449
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6671 - mae: 0.5451
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5313 - mae: 0.4769
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3099 - mae: 0.3765
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4094 - mae: 0.4450
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4513 - mae: 0.4525
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3696 - mae: 0.4307
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3931 - mae: 0.4372
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4589 - mae: 0.4127
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3162 - mae: 0.3512
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2644 - mae: 0.3432
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4415 - mae: 0.4062
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2299 - mae: 0.3186
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4591 - mae: 0.4145
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6370 - mae: 0.4136
# Epoch 17/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.4285 - mae: 0.3891
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3020 - mae: 0.3796
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2717 - mae: 0.3578
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1936 - mae: 0.3147
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2173 - mae: 0.3107
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2083 - mae: 0.3425
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1733 - mae: 0.2643
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2271 - mae: 0.3191
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2009 - mae: 0.3090
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1794 - mae: 0.2804
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1671 - mae: 0.2859
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1757 - mae: 0.2703
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1975 - mae: 0.2609
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3834 - mae: 0.3039
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1939 - mae: 0.3277
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5835 - mae: 0.4217
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3566 - mae: 0.3694
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2016 - mae: 0.3394
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3177 - mae: 0.3483
# Epoch 36/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2069 - mae: 0.3105
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3132 - mae: 0.3567
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2334 - mae: 0.3284
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2221 - mae: 0.3185
# Epoch 40/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1149 - mae: 0.2519
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3448 - mae: 0.3277
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1554 - mae: 0.2856
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2493 - mae: 0.2736
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3351 - mae: 0.3122
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1685 - mae: 0.2665
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1725 - mae: 0.3042
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1493 - mae: 0.2566
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1318 - mae: 0.2568
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1698 - mae: 0.2632
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1821 - mae: 0.2862
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1540 - mae: 0.3100
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1296 - mae: 0.2468
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1547 - mae: 0.2365
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1588 - mae: 0.2608
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2482 - mae: 0.2669
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1202 - mae: 0.2276
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2692 - mae: 0.3475
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1102 - mae: 0.2354
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1957 - mae: 0.2797
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2149 - mae: 0.2877
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2859 - mae: 0.3031
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1836 - mae: 0.2573
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0930 - mae: 0.2197
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1092 - mae: 0.2034
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0948 - mae: 0.2142
# Epoch 66/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1721 - mae: 0.2858
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2405 - mae: 0.3000
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1183 - mae: 0.2417
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2174 - mae: 0.3288
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1204 - mae: 0.2036
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1400 - mae: 0.2600
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1940 - mae: 0.2225
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1497 - mae: 0.2793
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1951 - mae: 0.2733
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1318 - mae: 0.2627
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1275 - mae: 0.2378
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1132 - mae: 0.2243
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1764 - mae: 0.2694
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1344 - mae: 0.1986
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1179 - mae: 0.2359
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0848 - mae: 0.1892
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1260 - mae: 0.2027
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1872 - mae: 0.2779
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1553 - mae: 0.2397
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2524 - mae: 0.2810
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1520 - mae: 0.2511
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1457 - mae: 0.2668
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2602 - mae: 0.2843
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1367 - mae: 0.2734
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1343 - mae: 0.2321
# Epoch 91/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1494 - mae: 0.2511
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1269 - mae: 0.2561
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1334 - mae: 0.2212
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1624 - mae: 0.2828
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1985 - mae: 0.2373
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2365 - mae: 0.2743
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1575 - mae: 0.2740
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2438 - mae: 0.2706
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1184 - mae: 0.2478
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2757 - mae: 0.3021
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f442370e290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5396 - mae: 0.4253
# processing fold # 2
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 0.8973 - mae: 0.7366
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6466 - mae: 0.5677
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5635 - mae: 0.5816
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2884 - mae: 0.4118
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5194 - mae: 0.5088
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3324 - mae: 0.3938
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2179 - mae: 0.3507
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2568 - mae: 0.3623
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1846 - mae: 0.3241
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2484 - mae: 0.3442
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5168 - mae: 0.4601
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2592 - mae: 0.3187
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2710 - mae: 0.3682
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3607 - mae: 0.3776
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3800 - mae: 0.4068
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6809 - mae: 0.4814
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4574 - mae: 0.3971
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2651 - mae: 0.3288
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2545 - mae: 0.3522
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1851 - mae: 0.2984
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3083 - mae: 0.3551
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2470 - mae: 0.2684
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4424 - mae: 0.4144
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2025 - mae: 0.3185
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2209 - mae: 0.2688
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2380 - mae: 0.3095
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1533 - mae: 0.2507
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2051 - mae: 0.3105
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2060 - mae: 0.3017
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2671 - mae: 0.3384
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3475 - mae: 0.3298
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4473 - mae: 0.3635
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1634 - mae: 0.2725
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3634 - mae: 0.3358
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3837 - mae: 0.3507
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1272 - mae: 0.2713
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1801 - mae: 0.2617
# Epoch 38/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2313 - mae: 0.2842
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5604 - mae: 0.3896
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1680 - mae: 0.3076
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1456 - mae: 0.2787
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1811 - mae: 0.2910
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1267 - mae: 0.2502
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1635 - mae: 0.2810
# Epoch 45/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.4266 - mae: 0.3560
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2034 - mae: 0.2790
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1650 - mae: 0.2781
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1669 - mae: 0.2707
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3762 - mae: 0.3382
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2394 - mae: 0.3047
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3186 - mae: 0.3364
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5021 - mae: 0.3615
# Epoch 53/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6032 - mae: 0.3815
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1903 - mae: 0.2708
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3004 - mae: 0.3494
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1402 - mae: 0.2528
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3611 - mae: 0.3692
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1040 - mae: 0.2236
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2210 - mae: 0.2776
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2439 - mae: 0.2881
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0945 - mae: 0.2328
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1648 - mae: 0.2974
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1431 - mae: 0.2165
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2895 - mae: 0.3409
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2228 - mae: 0.3067
# Epoch 66/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1995 - mae: 0.2713
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2429 - mae: 0.2902
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1801 - mae: 0.2918
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1850 - mae: 0.2636
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1997 - mae: 0.2767
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2209 - mae: 0.2921
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1426 - mae: 0.2352
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1606 - mae: 0.2431
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3796 - mae: 0.3120
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2520 - mae: 0.3374
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1614 - mae: 0.2717
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1703 - mae: 0.2721
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1708 - mae: 0.2601
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1986 - mae: 0.2968
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2563 - mae: 0.2708
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1368 - mae: 0.2360
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2255 - mae: 0.2876
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0795 - mae: 0.1991
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1037 - mae: 0.2195
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3143 - mae: 0.2896
# Epoch 86/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2581 - mae: 0.2555
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2581 - mae: 0.2874
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1432 - mae: 0.2497
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1738 - mae: 0.2657
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1841 - mae: 0.2756
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2167 - mae: 0.2548
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1786 - mae: 0.2620
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1313 - mae: 0.2284
# Epoch 94/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1266 - mae: 0.2253
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0997 - mae: 0.2293
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3806 - mae: 0.3707
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1758 - mae: 0.2555
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1502 - mae: 0.2571
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1475 - mae: 0.2513
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2318 - mae: 0.2884
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f442370eb90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2875 - mae: 0.3084
# processing fold # 3
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 1.1186 - mae: 0.8319
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.9218 - mae: 0.7411
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.9973 - mae: 0.7999
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7261 - mae: 0.6464
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.9053 - mae: 0.7181
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4073 - mae: 0.5362
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5453 - mae: 0.5787
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3380 - mae: 0.4364
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3894 - mae: 0.4392
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4307 - mae: 0.3968
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7812 - mae: 0.5816
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3163 - mae: 0.4055
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3875 - mae: 0.4111
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3816 - mae: 0.4179
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4333 - mae: 0.4447
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6653 - mae: 0.4406
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2534 - mae: 0.3303
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3398 - mae: 0.3581
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3805 - mae: 0.4235
# Epoch 20/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3730 - mae: 0.3785
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2491 - mae: 0.3386
# Epoch 22/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.5634 - mae: 0.4800
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3252 - mae: 0.3720
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2846 - mae: 0.3491
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3119 - mae: 0.3162
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2921 - mae: 0.4006
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5884 - mae: 0.4660
# Epoch 28/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2857 - mae: 0.3124
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4373 - mae: 0.4472
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2938 - mae: 0.3643
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5486 - mae: 0.4398
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2484 - mae: 0.3387
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2867 - mae: 0.3603
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.0053 - mae: 0.5661
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4713 - mae: 0.4129
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2130 - mae: 0.2916
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5038 - mae: 0.4488
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2437 - mae: 0.3257
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5517 - mae: 0.4229
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2613 - mae: 0.3374
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1667 - mae: 0.2859
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4158 - mae: 0.4038
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2111 - mae: 0.2977
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4210 - mae: 0.3989
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3113 - mae: 0.3643
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4679 - mae: 0.3883
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2481 - mae: 0.3130
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1543 - mae: 0.2325
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2968 - mae: 0.3778
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5140 - mae: 0.4109
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6526 - mae: 0.4582
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3577 - mae: 0.3587
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2747 - mae: 0.3468
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3820 - mae: 0.4226
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1722 - mae: 0.2907
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2768 - mae: 0.3109
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1752 - mae: 0.2931
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2492 - mae: 0.3423
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4546 - mae: 0.3837
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2932 - mae: 0.3298
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4368 - mae: 0.3994
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3203 - mae: 0.3704
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1514 - mae: 0.2808
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7339 - mae: 0.4626
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3314 - mae: 0.3324
# Epoch 66/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3424 - mae: 0.3663
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1559 - mae: 0.2907
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2936 - mae: 0.3602
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5897 - mae: 0.4414
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2579 - mae: 0.3137
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2713 - mae: 0.3584
# Epoch 72/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2700 - mae: 0.3260
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1485 - mae: 0.2754
# Epoch 74/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2155 - mae: 0.3239
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2894 - mae: 0.3622
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2349 - mae: 0.2839
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2535 - mae: 0.3367
# Epoch 78/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.7698 - mae: 0.4749
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2164 - mae: 0.3384
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2609 - mae: 0.3509
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3330 - mae: 0.3511
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3000 - mae: 0.3498
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4611 - mae: 0.3979
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2154 - mae: 0.2597
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1512 - mae: 0.2597
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1543 - mae: 0.2965
# Epoch 87/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1630 - mae: 0.2954
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3754 - mae: 0.3854
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3737 - mae: 0.4030
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2587 - mae: 0.3020
# Epoch 91/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3492 - mae: 0.3390
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3116 - mae: 0.3610
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3608 - mae: 0.3486
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2967 - mae: 0.3638
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1633 - mae: 0.2820
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2439 - mae: 0.3001
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4140 - mae: 0.3680
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4017 - mae: 0.3512
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1362 - mae: 0.2357
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4505 - mae: 0.3788
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4421378200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1267 - mae: 0.2549

# %% [markdown]
# # Scores

# %%
all_scores_relu
# Out:
# [0.3214185833930969,
#  0.32797762751579285,
#  0.37927746772766113,
#  0.3069368898868561]

# %%
all_scores_tanh
# Out:
# [0.3923054039478302,
#  0.3663097620010376,
#  0.4504547119140625,
#  0.39833417534828186]

# %%
all_scores_regular
# Out:
# [0.30322548747062683,
#  0.22789259254932404,
#  0.3054785430431366,
#  0.33022546768188477]

# %%
all_scores_drop
# Out:
# [0.5210351943969727,
#  0.4252856969833374,
#  0.3083527088165283,
#  0.25494322180747986]

# %% [markdown]
# # training on the training data

# %%
model_tanh = build_model('tanh')
model_tanh.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_tanh.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f441d4d6320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1083 - mae: 0.2444

# %%
model_relu = build_model('relu')
model_relu.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_relu.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4423fe34d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1107 - mae: 0.2562

# %%
model_regular = build_model_regular('relu')
model_regular.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_regular.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4422db54d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1052 - mae: 0.2092

# %%
model_drop = build_model_drop('relu')
model_drop.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_drop.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4422eeb3b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1150 - mae: 0.2562

# %% [markdown]
# # Prediction Section

# %%
test_l
# Out:
# array([ 0.01414832,  0.3725343 ,  1.3658801 ,  2.122337  , -1.004718  ,
#        -0.7045773 , -0.5886972 , -0.97443527, -0.763189  , -0.52312535,
#        -0.05301089, -0.3704908 , -0.5449216 , -0.80397296, -0.5536523 ,
#        -0.26059392,  0.6062484 ,  1.4864004 ,  2.5404336 ,  3.367835  ,
#        -0.8779702 , -0.09159691,  0.18192424, -0.7802841 , -0.50065756,
#        -0.9622245 , -0.6813769 , -0.5409531 ,  0.01463675,  0.12453365,
#         0.46643507, -0.1806134 ,  0.2687428 ,  0.4299249 ,  0.45129374,
#        -0.07511237,  2.3382235 ,  2.200547  , -0.49870384,  0.20280465,
#         0.26019526, -0.68430746, -0.7224051 , -0.65524584, -0.98066276,
#        -0.7889537 , -0.7547636 , -0.6888255 , -0.6277716 , -0.4983375 ,
#        -0.6020069 , -0.4139611 , -0.22347318, -0.54107517,  0.28217462,
#        -0.68430746, -0.6574438 , -0.59638995, -0.01027321,  0.056886  ,
#        -0.1329914 , -0.05362143,  0.3181964 ,  0.6155285 ], dtype=float32)

# %%
def predict(model, m):
  print(f" the actual price was : {test_l[m]* std_label + mean_label} " )
  return(f" the predicted price was : {(model.predict(test[m:m+1].reshape(1,test.shape[1]))) * std_label + mean_label} ")

# %%
x_tanh = predict(model_tanh,2)
x_tanh
# Out:
#  the actual price was : 24565.000309357743
# ' the predicted price was : [[21353.605]] '

# %%
x_relu = predict(model_relu,2)
x_relu
# Out:
#  the actual price was : 24565.000309357743
# ' the predicted price was : [[25539.66]] '

# %%
x_regular = predict(model_regular,2)
x_regular
# Out:
#  the actual price was : 24565.000309357743
# ' the predicted price was : [[23328.871]] '

# %%
x_drop = predict(model_drop,2)
x_drop
# Out:
#  the actual price was : 24565.000309357743
# ' the predicted price was : [[18196.834]] '

# %%
def plot_fn(mod):
  y_true = test_l* std_label + mean_label
  y_pred = mod.predict(test) * std_label + mean_label
  return y_true , y_pred.flatten()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
def plotting(mod, label):
  y_true, y_pred = plot_fn(mod)
  coef = np.polyfit(y_true,y_pred,1)
  poly1d_fn = np.poly1d(coef) 
  # poly1d_fn is now a function which takes in x and returns an estimate for y
  plt.figure()
  plt.plot(y_true,y_pred, 'yo', y_true, poly1d_fn(y_true), '--k')
  plt.title(label)
  plt.xlabel('Thousand Dollar True' )
  plt.ylabel('Thousand Dollar Predictions' )
  plt.xlim(0, 50000)
  plt.ylim(0, 50000)

# %%
plot_list = []
for i,j in enumerate([model_relu, model_tanh, model_regular, model_drop]):
  list_name = ['model_relu', 'model_tanh', 'model_regular', 'model_drop']
  plot_list.append(plotting(j,list_name[i]))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f442c2a6a70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f442c2a69e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f44266b6710> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:8 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f441f8f5830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
